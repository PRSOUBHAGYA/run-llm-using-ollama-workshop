# %% [markdown]
# # <font color="#007BFF">**Introduction to Ollama** </font>
#
# **Ollama** is an open-source framework designed to run large language models (LLMs) locally. It streamlines the process of downloading, managing, and interacting with models through a dedicated Python library and a local REST API.

# %% [markdown]
# ## <font color='#008080'>**1. Importing Library** </font>
#
# To interact with the Ollama service programmatically, we use the official `ollama` Python SDK. This library handles the communication between your script and the local Ollama server running on your machine.
#
# To convert Images to base64 encoded string we will use `base64` Python Package.

# %%
import ollama
import base64

# %% [markdown]
# ## <font color='#008080'>**2. Generating Response**
#
# The `generate` method is the core function for obtaining text completions. It is a **stateless** request where you provide a model name and a prompt. The model processes the input and returns a structured response containing the generated text and execution metadata.

# %%
response = ollama.generate(model='llama3.2:latest', prompt='Explain LLM to a 10th Class student in 5 lines.')

# %%
response
# Out:
# GenerateResponse(model='llama3.2:latest', created_at='2026-03-09T18:20:22.831349Z', done=True, done_reason='stop', total_duration=10198999333, load_duration=8791975458, prompt_eval_count=41, prompt_eval_duration=325220958, eval_count=99, eval_duration=1067662748, response="Here's an explanation of LLM that a 10th class student can understand:\n\nLarge Language Models (LLMs) are computer programs that can understand and generate human-like language. They learn from huge amounts of text data and can predict what words or sentences come next. This is done using complex algorithms and neural networks. LLMs are useful for tasks like answering questions, writing articles, and even translating languages. They're like super-smart chatbots that can have conversations with humans.", thinking=None, context=[128006, 9125, 128007, 271, 38766, 1303, 33025, 2696, 25, 6790, 220, 2366, 18, 271, 128009, 128006, 882, 128007, 271, 849, 21435, 445, 11237, 311, 264, 220, 605, 339, 3308, 5575, 304, 220, 20, 5238, 13, 128009, 128006, 78191, 128007, 271, 8586, 596, 459, 16540, 315, 445, 11237, 430, 264, 220, 605, 339, 538, 5575, 649, 3619, 1473, 35353, 11688, 27972, 320, 4178, 22365, 8, 527, 6500, 7620, 430, 649, 3619, 323, 7068, 3823, 12970, 4221, 13, 2435, 4048, 505, 6908, 15055, 315, 1495, 828, 323, 649, 7168, 1148, 4339, 477, 23719, 2586, 1828, 13, 1115, 374, 2884, 1701, 6485, 26249, 323, 30828, 14488, 13, 445, 11237, 82, 527, 5505, 369, 9256, 1093, 36864, 4860, 11, 4477, 9908, 11, 323, 1524, 67371, 15823, 13, 2435, 2351, 1093, 2307, 4773, 472, 6369, 63005, 430, 649, 617, 21633, 449, 12966, 13], logprobs=None)

# %%
print(response.response)
# Out:
# Here's an explanation of LLM that a 10th class student can understand:
#
# Large Language Models (LLMs) are computer programs that can understand and generate human-like language. They learn from huge amounts of text data and can predict what words or sentences come next. This is done using complex algorithms and neural networks. LLMs are useful for tasks like answering questions, writing articles, and even translating languages. They're like super-smart chatbots that can have conversations with humans.

# %% [markdown]
# ## <font color='#008080'>**3. Streaming the Response**
#
# By enabling the `stream` parameter, the model returns an **iterable generator**. This allows the application to receive and display tokens in real-time as they are produced, rather than waiting for the entire block of text to be finalized, which significantly improves the user experience.

# %%
response = ollama.generate(model='llama3.2:latest', prompt='Explain LLM to a 10th Class student',stream=True)
for res in response:
    print(res.response,end='')
# Out:
# Imagine you have a super smart friend who knows everything, but can't talk or write. That's kind of what a Large Language Model (LLM) is.
#
# A Large Language Model is a computer program that's trained on a huge amount of text data, like books, articles, and websites. This training helps the model learn patterns and relationships between words, so it can understand and generate human-like text.
#
# Think of it like this: when you ask a question or give a prompt to an LLM, it uses what it learned from the training data to come up with an answer or a response. It's like having a giant library of information at your fingertips!
#
# LLMs are great at many things, such as:
#
# 1. Answering questions: They can provide answers to a wide range of questions, from simple to complex ones.
# 2. Generating text: They can create text based on a prompt or topic, like a story or a summary.
# 3. Translation: They can translate text from one language to another.
# 4. Summarization: They can summarize long pieces of text into shorter, more digestible versions.
#
# The way LLMs work is by using something called "neural networks". These networks are like a series of layers of interconnected nodes (or "neurons") that process the input data. The more layers you have, the more complex the model becomes!
#
# Here's an analogy to help you understand how LLMs work:
#
# Imagine you're trying to recognize a picture of a cat. You show the model a picture of a cat, and it looks at the pixels ( tiny squares of color) in the image. The model then uses these pixels to recognize the shape, pattern, and features of the cat, which it's been trained to recognize.
#
# In the same way, when you input text into an LLM, it looks at the patterns and relationships between words to generate a response. It's a powerful tool that's changing the way we interact with technology and each other!
#
# I hope this explanation helped you understand what LLMs are and how they work!

# %% [markdown]
# ## <font color='#008080'>**4. Working with Images**
#
# Ollama supports **Multimodal LLMs** (such as *gemma*,*Llava*), which are capable of processing both text and visual data simultaneously to perform "Visual Question Answering" (VQA).

# %% [markdown]
# ### <font color='#008080'>**4.1. Single Image**

# %%
image_path = 'transformer_architecture.jpg'

# %%
with open(image_path,"rb") as f: # operning image in binary mode 
    image_bytes= f.read()    # reading the image 
image_64= base64.b64encode(image_bytes).decode("utf-8") # encoding the image in 64 bits.

# %%
response = ollama.generate(model='gemma3:4b', prompt='Explain the image briefly',images=[image_64],stream=True)
for res in response:
    print(res.response,end='')
# Out:
# Here's a breakdown of the image, explaining the architecture of a masked multi-head self-attention layer:
#
# **Overall Structure:**
#
# The image shows a core block of a transformer layer. This block performs a multi-head self-attention mechanism, which is a key component of transformers for processing sequential data like text.
#
# **Key Components and Flow:**
#
# 1. **Input Embedding:** The input sequence is first converted into embeddings (dense vector representations) of each element. These embeddings are then shifted to the right (as shown in the output).
#
# 2. **Positional Encoding:**  Positional encoding adds information about the position of each element in the sequence to the embeddings. This is crucial because self-attention doesn't inherently understand the order of the sequence.
#
# 3. **Add & Norm (First):**
#    * The output of the input embedding + positional encoding is fed into the first "Add & Norm" block. This block performs:
#       * **Add:** Residual connection (adds the input to the output).
#       * **Norm:** Layer normalization (scales and shifts the output to have zero mean and unit variance).
#
# 4. **Multi-Head Attention:**
#     * This is the core of the self-attention mechanism. It works as follows:
#        *  It projects the input embeddings into multiple "heads" (N× heads in this diagram).
#        * Each head calculates attention weights, determining how much each element in the sequence should attend to every other element (including itself).
#        * The attention weights are used to create a weighted sum of the input embeddings, producing a contextually enriched representation for each element.
#
# 5. **Add & Norm (Second):**
#    * The output of the Multi-Head Attention block is passed through a second "Add & Norm" block, again performing residual connections and layer normalization.
#
# 6. **Masked Multi-Head Attention (Final):**
#    * This is a crucial step! The final multi-head attention layer is *masked*. This means that during the attention calculation, the model can only attend to the current element and elements *before* it in the sequence. It cannot "see the future".  This masking is essential for training autoregressive models (like language models) where the model needs to predict the next element based on the previous elements.
#
# 7. **Output Embedding:** Finally, the output of the masked multi-head attention is combined with the output embedding (shifted right) to form the final output.
#
# **In essence, this block takes a sequence of embeddings, learns relationships between elements in the sequence through self-attention, and then produces a new, contextually enriched representation of the sequence.**
#
# **Key Concepts Illustrated:**
#
# *   **Self-Attention:**  The model attends to different parts of the same input sequence to understand relationships.
# *   **Multi-Head:**  Allows the model to learn different types of relationships.
# *   **Masking:** Ensures that the model only uses past information to predict the future.
# *   **Residual Connections and Layer Normalization:**  Common techniques in transformers for training stability and faster convergence.
#
# Let me know if you'd like a more detailed explanation of any of these components or how this block fits into the overall transformer architecture!

# %% [markdown]
# ### <font color='#008080'>**4.2. Multiple Images**

# %%
image_paths = ['transformer_architecture.jpg','gemma_benchmark_score.jpg']
base_64_images = []
for each_image_path in image_paths:
    with open(each_image_path,"rb") as f: 
        image_bytes= f.read()
    image_64= base64.b64encode(image_bytes).decode("utf-8")
    base_64_images.append(image_64)

# %%
response = ollama.generate(model='gemma3:4b', prompt='Explain the images briefly',images=base_64_images,stream=True)
for res in response:
    print(res.response,end='')
# Out:
# Okay, let's break down the images you provided.
#
# **Image 1: Architecture Diagram**
#
# *   This image shows the architecture of a "Multi-Head Attention" block, a key component of transformer models like those used in large language models.
# *   **Inputs:** The block receives two inputs:
#     *   **Input Embedding:** The original input sequence (tokens).
#     *   **Positional Encoding:**  Information about the order of the sequence elements.
# *   **Process:**
#     *   The inputs are combined through addition.
#     *   The combined representation passes through a "Feed Forward" layer.
#     *   The result is then "Add & Norm" (additive normalization), a technique to stabilize training.
#     *   The "Multi-Head Attention" layer processes the data, allowing the model to attend to different parts of the sequence simultaneously.
# *   **Outputs:** The block outputs a transformed representation of the input.
#
# **Image 2: Performance Benchmarks**
#
# *   This image shows the performance of Llama 2 and Gemma on a variety of benchmarks.
# *   **Llama 2:** The 7B and 13B models show strong performance across several categories.
# *   **Gemma:** Gemma is a smaller model that still performs well on tasks such as:
#     *   **General:** Performs well on a multi-subject benchmark.
#     *   **Reasoning:**  Shows strong results on diverse reasoning tasks.
#     *   **Math:**  Performs much better on basic arithmetic than Llama 2.
#     *   **Code

# %%
response = ollama.generate(model='llama3.2:latest',system='You are technical poet who describes concept via poem.' ,prompt='Explain LLM to a 10th Class student',stream=True)
for res in response:
    print(res.response,end='')

# %% [markdown]
# ## <font color='#008080'>**5. Hyperparameter Tuning**
#
# Model behavior can be customized using the `options` dictionary. These parameters allow you to fine-tune the "creativity," deterministic nature, and resource usage of the local LLM.
#
# * **`temperature`**: Adjusts the randomness of the output. Higher values (e.g., $1.5$) make the model more creative, while lower values (e.g., $0.1$) make it more deterministic. (Default: $0.8$)
# * **`top_p`**: Nucleus sampling; limits the model to consider tokens whose cumulative probability reaches $P$. (Default: $0.9$)
# * **`top_k`**: Limits the vocabulary to the $K$ most likely next words, reducing the chance of nonsense. (Default: $40$)
# * **`min_p`**: Sets a minimum probability threshold relative to the most likely token to balance quality and variety.
# * **`repeat_penalty`**: Penalizes repetitions. Higher values (e.g., $1.2$) discourage the model from repeating phrases. (Default: $1.1$)
# * **`repeat_last_n`**: Sets how far back the model looks to prevent repetition. $0$ disables it; $-1$ looks at the entire context. (Default: $64$)
# * **`presence_penalty`**: Encourages the model to talk about new topics by penalizing tokens that have already appeared.
# * **`frequency_penalty`**: Specifically targets repetitive word usage based on how often they have appeared.
# * **`num_ctx`**: Sets the size of the context window (in tokens). This is the model's "memory" for the current conversation. (Default: $2048$)
# * **`num_predict`**: The maximum number of tokens to generate. Set to $-1$ for infinite generation until a stop token is hit.
# * **`stop`**: A list of specific strings that will trigger the model to stop generating immediately.
# * **`seed`**: Sets the random number seed. Using a specific integer (e.g., $42$) makes the output reproducible.
# * **`num_thread`**: Sets the number of CPU threads used. Ollama usually optimizes this automatically.
# * **`mirostat`**: Enables Mirostat sampling to control perplexity ($0$ = disabled, $1$ = Mirostat, $2$ = Mirostat 2.0).

# %%
response = ollama.generate(model='llama3.2:latest', prompt='Explain LLM to a 10th Class student',stream=True, options={
    'temperature':0.9,
    'top_p':0.1
})
for res in response:
    print(res.response,end='')

# %% [markdown]
# ## <font color='#008080'>**6. Basic Ollama Commands**
#
# The library provides several management functions that mirror the CLI commands, allowing for automated model administration within your Python environment.

# %% [markdown]
# ### <font color='#008080'>**6.1. Available LLMs in Your Machine**
#
# The `list` function retrieves a catalog of all models currently stored on your local disk. It includes details such as the model version, file size, and the date it was last modified.

# %%
local_models= ollama.list()
print(local_models)
print("**************************")

for i in local_models["models"]:
    print(i["model"], end='   ')
    print(str(round(i["size"]/1073741824,2))+"GB")

# %% [markdown]
# ### <font color='#008080'>**6.2. Download LLM from Ollama Hub**
#
# The `pull` function is used to download new model weights from the **Ollama Registry**. It fetches the required layers and configures them for your specific hardware (CPU/GPU) automatically.

# %%
model_name="deepseek-r1"
progess = ollama.pull(model_name, stream=True)

for i in progess:
    print(i)

# %% [markdown]
# ### <font color='#008080'>**6.3. Details of an LLM**
#
# The `show` function provides a deep dive into a specific model's **Modelfile**. This includes the underlying architecture, the license information, and the specific **System Prompt** used to define the AI's persona.

# %%
models_details = ollama.show("gemma3:4b")
print(models_details.dict())

# %%
model_dict= models_details.dict()
print(model_dict["capabilities"])
print(model_dict["parameters"])
